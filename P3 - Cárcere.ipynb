# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
db = pd.read_csv('3-Year_Recidivism_for_Offenders_Released_from_Prison_in_Iowa_elaborated.csv')

# %%
db
#db["Race - Ethnicity"].value_counts()
etnia_motivo = pd.crosstab(db["Race - Ethnicity"], db["Convicting Offense Type"], normalize=True)*100
etnia_motivo
# Out:
# Convicting Offense Type                               Drug     Other  \
# Race - Ethnicity
# American Indian or Alaska Native - Hispanic       0.030781  0.000000
# American Indian or Alaska Native - Non-Hispanic   0.361678  0.076953
# Asian or Pacific Islander - Hispanic              0.011543  0.000000
# Asian or Pacific Islander - Non-Hispanic          0.207772  0.034629
# Black -                                           0.000000  0.003848
# Black - Hispanic                                  0.034629  0.000000
# Black - Non-Hispanic                              7.406695  1.223548
# N/A -                                             0.003848  0.003848
# White -                                           0.007695  0.000000
# White - Hispanic                                  1.973836  0.161601
# White - Non-Hispanic                             20.388611  3.532128
#
# Convicting Offense Type                           Property  Public Order  \
# Race - Ethnicity
# American Indian or Alaska Native - Hispanic       0.015391      0.000000
# American Indian or Alaska Native - Non-Hispanic   0.615621      0.400154
# Asian or Pacific Islander - Hispanic              0.000000      0.003848
# Asian or Pacific Islander - Non-Hispanic          0.250096      0.073105
# Black -                                           0.003848      0.000000
# Black - Hispanic                                  0.053867      0.011543
# Black - Non-Hispanic                              6.290881      2.727972
# N/A -                                             0.007695      0.003848
# White -                                           0.011543      0.007695
# White - Hispanic                                  1.135052      1.073490
# White - Non-Hispanic                             19.957676      9.557522
#
# Convicting Offense Type                            Violent
# Race - Ethnicity
# American Indian or Alaska Native - Hispanic       0.030781
# American Indian or Alaska Native - Non-Hispanic   0.477107
# Asian or Pacific Islander - Hispanic              0.003848
# Asian or Pacific Islander - Non-Hispanic          0.173144
# Black -                                           0.000000
# Black - Hispanic                                  0.042324
# Black - Non-Hispanic                              5.856098
# N/A -                                             0.000000
# White -                                           0.019238
# White - Hispanic                                  1.512120
# White - Non-Hispanic                             14.220854
